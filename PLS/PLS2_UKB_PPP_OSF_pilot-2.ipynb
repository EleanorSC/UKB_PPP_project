# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.2.0-cp312-cp312-macosx_10_9_x86_64.whl.metadata (19 kB)
# Collecting numpy<2,>=1.26.0 (from pandas)
#   Downloading numpy-1.26.3-cp312-cp312-macosx_10_9_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas) (2.8.2)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2023.4-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2023.4-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.2.0-cp312-cp312-macosx_10_9_x86_64.whl (12.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.5/12.5 MB 10.8 MB/s eta 0:00:0000:0100:01
# Downloading numpy-1.26.3-cp312-cp312-macosx_10_9_x86_64.whl (20.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.3/20.3 MB 12.1 MB/s eta 0:00:0000:0100:01
# Downloading pytz-2023.4-py2.py3-none-any.whl (506 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.5/506.5 kB 7.6 MB/s eta 0:00:00:00:01
# Downloading tzdata-2023.4-py2.py3-none-any.whl (346 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.6/346.6 kB 6.8 MB/s eta 0:00:00:00:01
# Installing collected packages: pytz, tzdata, numpy, pandas
# Successfully installed numpy-1.26.3 pandas-2.2.0 pytz-2023.4 tzdata-2023.4

# %% [markdown]
# # PLS2 for proteomics and DTI data initial test run

# %%
import pandas as pd
# Out:
# /var/folders/_0/pgrzqnfd5zj00cq9q5x3sbqm0000gn/T/ipykernel_86764/4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# !pip install pyarrow
# Out:
# Collecting pyarrow
#   Downloading pyarrow-15.0.0-cp312-cp312-macosx_10_15_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: numpy<2,>=1.16.6 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pyarrow) (1.26.3)
# Downloading pyarrow-15.0.0-cp312-cp312-macosx_10_15_x86_64.whl (27.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.1/27.1 MB 12.5 MB/s eta 0:00:0000:0100:01
# Installing collected packages: pyarrow
# Successfully installed pyarrow-15.0.0

# %%
# !pip install numpy
# !pip install scikit-learn
# Out:
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (1.26.3)
# Collecting scikit-learn
#   Downloading scikit_learn-1.4.0-1-cp312-cp312-macosx_10_9_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scikit-learn) (1.26.3)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Downloading scipy-1.12.0-cp312-cp312-macosx_10_9_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 1.1 MB/s eta 0:00:00a 0:00:01
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn)
#   Downloading threadpoolctl-3.2.0-py3-none-any.whl.metadata (10.0 kB)
# Downloading scikit_learn-1.4.0-1-cp312-cp312-macosx_10_9_x86_64.whl (11.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 15.2 MB/s eta 0:00:0000:0100:01
# Downloading joblib-1.3.2-py3-none-any.whl (302 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 kB 7.3 MB/s eta 0:00:00:00:01
# Downloading scipy-1.12.0-cp312-cp312-macosx_10_9_x86_64.whl (38.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.9/38.9 MB 10.9 MB/s eta 0:00:0000:0100:01
# Downloading threadpoolctl-3.2.0-py3-none-any.whl (15 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.3.2 scikit-learn-1.4.0 scipy-1.12.0 threadpoolctl-3.2.0

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.8.2-cp312-cp312-macosx_10_12_x86_64.whl.metadata (5.8 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.2.0-cp312-cp312-macosx_10_9_x86_64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.47.2-cp312-cp312-macosx_10_9_x86_64.whl.metadata (157 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.6/157.6 kB 2.4 MB/s eta 0:00:0000:01
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.5-cp312-cp312-macosx_10_9_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy<2,>=1.21 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib) (1.26.3)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib) (23.2)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-10.2.0-cp312-cp312-macosx_10_10_x86_64.whl.metadata (9.7 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.1.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.8.2-cp312-cp312-macosx_10_12_x86_64.whl (7.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 11.4 MB/s eta 0:00:0000:0100:01
# Downloading contourpy-1.2.0-cp312-cp312-macosx_10_9_x86_64.whl (259 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.3/259.3 kB 2.7 MB/s eta 0:00:0000:0100:01
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.47.2-cp312-cp312-macosx_10_9_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 10.3 MB/s eta 0:00:0000:0100:01
# Downloading kiwisolver-1.4.5-cp312-cp312-macosx_10_9_x86_64.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 2.1 MB/s eta 0:00:00
# Downloading pillow-10.2.0-cp312-cp312-macosx_10_10_x86_64.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 9.5 MB/s eta 0:00:00:00:0100:01
# Downloading pyparsing-3.1.1-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.1/103.1 kB 3.2 MB/s eta 0:00:00
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.0 cycler-0.12.1 fonttools-4.47.2 kiwisolver-1.4.5 matplotlib-3.8.2 pillow-10.2.0 pyparsing-3.1.1

# %%
# Load relevant packages 
import pandas as pd
import numpy as np
from sklearn.cross_decomposition import PLSRegression
import matplotlib.pyplot as plt

# %% [markdown]
# # Load relevant data for pilot test

# %%
# Check what's in directory
import os

current_directory = os.getcwd()

print(current_directory)
# Out:
# /Users/eleanorc_worklaptop/Desktop/UKB_Proteomics/UKB_PPP_python

# %%
proteomics = "/Users/eleanorc_worklaptop/Desktop/UKB_Proteomics/UKB_PPP_python/ST3_UKB_proteins.csv"
df_p_data = pd.read_csv(proteomics)
df_p_data
# Out:
#                 UKBPPP ProteinID  Olink ID Assay Target    Protein panel  \
# 0      AARSD1:Q9BTE6:OID21311:v1  OID21311       AARSD1         Oncology
# 1     ABHD14B:Q96IU4:OID20921:v1  OID20921      ABHD14B        Neurology
# 2        ABL1:P00519:OID21280:v1  OID21280         ABL1         Oncology
# 3       ACAA1:P09110:OID21269:v1  OID21269        ACAA1         Oncology
# 4        ACAN:P16112:OID20159:v1  OID20159         ACAN  Cardiometabolic
# ...                          ...       ...          ...              ...
# 1467    XRCC4:Q13426:OID20869:v1  OID20869        XRCC4        Neurology
# 1468     YES1:P07947:OID21348:v1  OID21348         YES1         Oncology
# 1469   YTHDF3:Q7Z739:OID20478:v1  OID20478       YTHDF3     Inflammation
# 1470   ZBTB16:Q05516:OID21205:v1  OID21205       ZBTB16         Oncology
# 1471   ZBTB17:Q13105:OID20082:v1  OID20082       ZBTB17  Cardiometabolic
#
#      Gene symbol UniProt Gene CHROM Gene start   Gene end Dilution factor  \
# 0         AARSD1  Q9BTE6         17   42950526   42964498             1:1
# 1        ABHD14B  Q96IU4          3   51968510   51983409             1:1
# 2           ABL1  P00519          9  130713016  130887675             1:1
# 3          ACAA1  P09110          3   38103129   38137242             1:1
# 4           ACAN  P16112         15   88803436   88875353            1:10
# ...          ...     ...        ...        ...        ...             ...
# 1467       XRCC4  Q13426          5   83077498   83353787             1:1
# 1468        YES1  P07947         18     721588     812546             1:1
# 1469      YTHDF3  Q7Z739          8   63168553   63212786             1:1
# 1470      ZBTB16  Q05516         11  114059041  114256765             1:1
# 1471      ZBTB17  Q13105          1   15941869   15976132             1:1
#
#      % of samples below LOD  Coefficient of variation (median %)
# 0                     0.05%                                 4.78
# 1                     0.04%                                 8.97
# 2                     0.04%                                 6.03
# 3                    17.20%                                12.97
# 4                     0.13%                                 6.18
# ...                     ...                                  ...
# 1467                 80.94%                                 7.55
# 1468                  0.04%                                10.59
# 1469                 10.88%                                13.11
# 1470                  0.51%                                 8.49
# 1471                  0.03%                                 7.83
#
# [1472 rows x 12 columns]

# %%
# Load DTI data
neuroimaging_subset = "/Users/eleanorc_worklaptop/Desktop/UKB_Proteomics/UKB_PPP_python/merged_data.csv"

df_neuroimaging = pd.read_csv(neuroimaging_subset)

df_neuroimaging
# Out:
#       Unnamed: 0      eid     GZMB   GRPEL1    GSAP    GSTA1    GSTA3   GSTP1  \
# 0              1  1000573  0.18050  0.44505  0.3517  0.87555  0.59995  0.4293
# 1              2  1000893  0.88645  0.69160  0.6700  1.24515  0.67090  0.8054
# 2              3  1001028  1.37140  0.78770  2.0522  0.46210  0.73440  0.3075
# 3              4  1003537  0.57010  0.43875  0.3803  0.43135  0.28970  0.4099
# 4              5  1004616  1.19495  0.83780  0.2743  0.56105  0.31370  1.5987
# ...          ...      ...      ...      ...     ...      ...      ...     ...
# 4639        4640  6018609  0.00650  0.45365  0.4506  1.42485  1.10560  0.6354
# 4640        4641  6019358  0.49865  0.02620  0.5769  0.61225  0.49330  0.5430
# 4641        4642  6021143  0.10620  2.29245  0.1899  0.03165  0.36700  1.0386
# 4642        4643  6021217  0.02515  0.15630  0.4839  0.79975  4.44390  0.0259
# 4643        4644  6021890  0.79615  0.58130  0.2765  1.50025  1.87330  0.3025
#
#        GUCA2A     GUSB  ...    lML_FA    rML_FA   lPTR_FA   rPTR_FA   lSLF_FA  \
# 0     0.13085  0.90860  ...  0.425137  0.438404  0.477601  0.466786  0.486486
# 1     0.22295  0.17655  ...  0.407959  0.397717  0.445529  0.457740  0.453780
# 2     0.71600  0.40510  ...  0.410745  0.450009  0.477916  0.441603  0.451860
# 3     0.00475  0.62660  ...  0.430355  0.439236  0.491488  0.471265  0.450530
# 4     0.33875  0.13995  ...  0.410290  0.408738  0.474783  0.450130  0.447044
# ...       ...      ...  ...       ...       ...       ...       ...       ...
# 4639  0.66945  0.28730  ...  0.463914  0.468890  0.445366  0.452633  0.430563
# 4640  0.55165  1.00795  ...  0.420189  0.414230  0.451537  0.454354  0.427003
# 4641  0.13275  1.36590  ...  0.413580  0.398320  0.468904  0.474296  0.457283
# 4642  0.15815  0.19085  ...  0.432379  0.425174  0.444384  0.479776  0.454680
# 4643  0.07095  0.47385  ...  0.389003  0.414311  0.448412  0.451519  0.449770
#
#        rSLF_FA   lSTR_FA   rSTR_FA   lUnc_FA   rUnc_FA
# 0     0.435698  0.434628  0.437619  0.414991  0.403708
# 1     0.433911  0.409192  0.423134  0.378078  0.373331
# 2     0.430216  0.422117  0.421530  0.376068  0.365023
# 3     0.446036  0.429410  0.430935  0.412622  0.406120
# 4     0.431624  0.451923  0.441271  0.368224  0.360642
# ...        ...       ...       ...       ...       ...
# 4639  0.407339  0.427389  0.405904  0.363829  0.351309
# 4640  0.419351  0.419468  0.429952  0.370552  0.380164
# 4641  0.457668  0.439893  0.454022  0.429197  0.464371
# 4642  0.449540  0.431674  0.433359  0.397299  0.383125
# 4643  0.442170  0.418830  0.418845  0.404682  0.382877
#
# [4644 rows x 1492 columns]

# %%
# Tidy this df
df_neuroimaging.drop(columns=['eid'], inplace=True)
df_neuroimaging.head()
# Out:
#    Unnamed: 0     GZMB   GRPEL1    GSAP    GSTA1    GSTA3   GSTP1   GUCA2A  \
# 0           1  0.18050  0.44505  0.3517  0.87555  0.59995  0.4293  0.13085
# 1           2  0.88645  0.69160  0.6700  1.24515  0.67090  0.8054  0.22295
# 2           3  1.37140  0.78770  2.0522  0.46210  0.73440  0.3075  0.71600
# 3           4  0.57010  0.43875  0.3803  0.43135  0.28970  0.4099  0.00475
# 4           5  1.19495  0.83780  0.2743  0.56105  0.31370  1.5987  0.33875
#
#       GUSB     GYS1  ...    lML_FA    rML_FA   lPTR_FA   rPTR_FA   lSLF_FA  \
# 0  0.90860  0.20335  ...  0.425137  0.438404  0.477601  0.466786  0.486486
# 1  0.17655  0.86730  ...  0.407959  0.397717  0.445529  0.457740  0.453780
# 2  0.40510  2.33680  ...  0.410745  0.450009  0.477916  0.441603  0.451860
# 3  0.62660  0.97315  ...  0.430355  0.439236  0.491488  0.471265  0.450530
# 4  0.13995  0.92150  ...  0.410290  0.408738  0.474783  0.450130  0.447044
#
#     rSLF_FA   lSTR_FA   rSTR_FA   lUnc_FA   rUnc_FA
# 0  0.435698  0.434628  0.437619  0.414991  0.403708
# 1  0.433911  0.409192  0.423134  0.378078  0.373331
# 2  0.430216  0.422117  0.421530  0.376068  0.365023
# 3  0.446036  0.429410  0.430935  0.412622  0.406120
# 4  0.431624  0.451923  0.441271  0.368224  0.360642
#
# [5 rows x 1491 columns]

# %%
# Assign white matter tracts and proteins from dataframes

wm_cols = ["FMaj_FA", "FMin_FA", "lAR_FA", "lATR_FA", "lCingG_FA", "lCingPH_FA",
           "lCST_FA", "lIFOF_FA", "lILF_FA", "lML_FA", "lPTR_FA", "lSLF_FA",
           "lSTR_FA", "lUnc_FA", "MCP_FA", "rAR_FA", "rATR_FA", "rCingG_FA",
           "rCingPH_FA", "rCST_FA", "rIFOF_FA", "rILF_FA", "rML_FA", "rPTR_FA",
           "rSLF_FA", "rSTR_FA", "rUnc_FA"]

wm = df_neuroimaging[wm_cols]

proteins = df_neuroimaging[[col for col in df_neuroimaging.columns if col not in wm_cols]]

proteins
# Out:
#       Unnamed: 0     GZMB   GRPEL1    GSAP    GSTA1    GSTA3   GSTP1   GUCA2A  \
# 0              1  0.18050  0.44505  0.3517  0.87555  0.59995  0.4293  0.13085
# 1              2  0.88645  0.69160  0.6700  1.24515  0.67090  0.8054  0.22295
# 2              3  1.37140  0.78770  2.0522  0.46210  0.73440  0.3075  0.71600
# 3              4  0.57010  0.43875  0.3803  0.43135  0.28970  0.4099  0.00475
# 4              5  1.19495  0.83780  0.2743  0.56105  0.31370  1.5987  0.33875
# ...          ...      ...      ...     ...      ...      ...     ...      ...
# 4639        4640  0.00650  0.45365  0.4506  1.42485  1.10560  0.6354  0.66945
# 4640        4641  0.49865  0.02620  0.5769  0.61225  0.49330  0.5430  0.55165
# 4641        4642  0.10620  2.29245  0.1899  0.03165  0.36700  1.0386  0.13275
# 4642        4643  0.02515  0.15630  0.4839  0.79975  4.44390  0.0259  0.15815
# 4643        4644  0.79615  0.58130  0.2765  1.50025  1.87330  0.3025  0.07095
#
#          GUSB     GYS1  ...    PRDX1    NAAA     NGF    MITD1     MMP1  \
# 0     0.90860  0.20335  ...  0.34580  1.0442  0.0900  0.67620  0.74310
# 1     0.17655  0.86730  ...  1.22255  1.0864  0.0038  1.36675  0.44735
# 2     0.40510  2.33680  ...  1.47190  0.3559  0.0624  1.56560  1.45220
# 3     0.62660  0.97315  ...  0.02150  0.3292  0.0640  0.41860  1.32090
# 4     0.13995  0.92150  ...  0.30125  0.4677  0.0376  0.72735  0.58605
# ...       ...      ...  ...      ...     ...     ...      ...      ...
# 4639  0.28730  0.39795  ...  0.52620  0.4138  0.3772  0.36270  0.36140
# 4640  1.00795  0.50570  ...  1.00565  0.5498  0.2122  0.59325  0.62125
# 4641  1.36590  0.57045  ...  0.52640  0.3326  0.0231  0.12760  1.95350
# 4642  0.19085  0.15670  ...  0.16195  0.1605  0.1358  0.75825  0.61365
# 4643  0.47385  0.72170  ...  0.36175  1.0208  0.0068  0.57415  0.01315
#
#         OBP2B    PCOLCE     PAEP      NPM1  NMNAT1
# 0     0.49010  0.039624  1.86860  0.011198  0.0622
# 1     0.70345  0.039624  3.49205  0.515900  1.2389
# 2     1.18670  0.039624  0.00000  0.011198  0.1559
# 3     1.41025  0.039624  1.36310  0.011198  0.9298
# 4     0.85185  0.039624  0.16445  0.011198  0.9957
# ...       ...       ...      ...       ...     ...
# 4639  1.02420  0.306250  0.92680  0.011198  0.7953
# 4640  0.05985  0.009800  1.64825  0.251700  0.1440
# 4641  0.02335  0.039624  0.44200  0.011198  0.5101
# 4642  0.03335  0.039624  1.31365  0.011198  0.1079
# 4643  0.56555  0.039624  0.54115  0.011198  0.0685
#
# [4644 rows x 1464 columns]

# %% [markdown]
# ## Build a dictionary

# %%
# Create a dictionary called lookup based on information obtained from the proteins df and other predefined dictionaries and lists
lookup = {}

colors = {"Inflammation": "tab:red", "Neurology": "tab:blue", "Cardiometabolic": "tab:orange", "Oncology": "tab:green"}

for index in range(0,len(proteins.columns)):
    name = proteins.columns[index]
    panel = df_p_data[df_p_data['Assay Target'] == name]['Protein panel'].to_list()
    if index == 0:
        panel = ""
        color = "tab:grey"
    else:
        panel = panel[0]
        color = colors[panel]
    lookup[index] = {"name": name, "panel": panel, "color": color}

#lookup

# %%
def dictionary_head(dictionary, num_items=5):
    """
    Display the first 'num_items' key-value pairs from a dictionary.
    
    Args:
    dictionary (dict): The dictionary to display.
    num_items (int): Number of items to display (default is 5).
    """
    items_to_display = list(dictionary.items())[:num_items]
    for key, value in items_to_display:
        print(f"{key}: {value}")

# run function to glimpse() / skimr::skim()
dictionary_head(lookup)
# Out:
# 0: {'name': 'Unnamed: 0', 'panel': '', 'color': 'tab:grey'}
# 1: {'name': 'GZMB', 'panel': 'Inflammation', 'color': 'tab:red'}
# 2: {'name': 'GRPEL1', 'panel': 'Oncology', 'color': 'tab:green'}
# 3: {'name': 'GSAP', 'panel': 'Oncology', 'color': 'tab:green'}
# 4: {'name': 'GSTA1', 'panel': 'Cardiometabolic', 'color': 'tab:orange'}

# %%
# Test our dictionary : 
lookup[1]
# Out:
# {'name': 'GZMB', 'panel': 'Inflammation', 'color': 'tab:red'}

# %%
# match up items
df2 = df_p_data[['Assay Target', 'Protein panel']]

df2[df2['Assay Target'] == 'THBS4']
# Out:
#      Assay Target    Protein panel
# 1352        THBS4  Cardiometabolic

# %% [markdown]
# ## Run PLS2

# %%
# PLS2 attempt
pls2 = PLSRegression(n_components=2)

pls2.fit(proteins, wm)
# Out:
# PLSRegression()

# %%
[lookup[i]['color'] for i in range(0,len(pls2.x_loadings_))]
# Out:
# ['tab:grey',
#  'tab:red',
#  'tab:green',
#  'tab:green',
#  'tab:orange',
#  'tab:green',
#  'tab:blue',
#  'tab:blue',
#  'tab:orange',
#  'tab:orange',
#  'tab:red',
#  'tab:green',
#  'tab:orange',
#  'tab:green',
#  'tab:green',
#  'tab:blue',
#  'tab:green',
#  'tab:blue',
#  'tab:green',
#  'tab:green',
#  'tab:red',
#  'tab:blue',
#  'tab:red',
#  'tab:green',
#  'tab:orange',
#  'tab:green',
#  'tab:green',
#  'tab:orange',
#  'tab:green',
#  'tab:blue',
#  'tab:orange',
#  'tab:orange',
#  'tab:orange',
#  'tab:blue',
#  'tab:red',
#  'tab:red',
#  'tab:green',
#  'tab:green',
#  'tab:blue',
#  'tab:orange',
#  'tab:orange',
#  'tab:orange',
#  'tab:blue',
#  'tab:orange',
#  'tab:red',
#  'tab:orange',
#  'tab:red',
#  'tab:orange',
#  'tab:orange',
#  'tab:orange',
#  'tab:red',
#  'tab:orange',
#  'tab:green',
#  'tab:blue',
#  'tab:orange',
#  'tab:green',
#  'tab:red',
#  'tab:red',
#  'tab:blue',
#  'tab:red',
#  'tab:green',
#  'tab:blue',
#  'tab:orange',
#  'tab:orange',
#  'tab:orange',
#  'tab:red',
#  'tab:red',
#  'tab:green',
#  'tab:orange',
#  'tab:red',
#  'tab:red',
#  'tab:green',
#  'tab:orange',
#  'tab:blue',
#  'tab:orange',
#  'tab:green',
#  'tab:green',
#  'tab:green',
#  'tab:green',
#  'tab:red',
#  'tab:blue',
#  'tab:red',
#  'tab:orange',
#  'tab:green',
#  'tab:orange',
#  'tab:red',
#  'tab:orange',
#  'tab:green',
#  'tab:green',
#  'tab:red',
#  'tab:green',
#  'tab:red',
#  'tab:red',
#  'tab:orange',
#  'tab:green',
#  'tab:red',
#  'tab:red',
#  'tab:orange',
#  'tab:blue',
#  'tab:blue',
#  'tab:orange',
#  'tab:red',
#  'tab:orange',
#  'tab:blue',
#  'tab:green',
#  'tab:blue',
#  'tab:green',
#  'tab:orange',
#  'tab:red',
#  'tab:red',
#  'tab:orange',
#  'tab:red',
#  'tab:orange',
#  'tab:red',
#  'tab:orange',
#  'tab:green',
#  'tab:red',
#  'tab:orange',
#  'tab:blue',
#  'tab:red',
#  'tab:red',
#  'tab:green',
#  'tab:blue',
#  'tab:green',
#  'tab:green',
#  'tab:blue',
#  'tab:green',
#  'tab:green',
#  'tab:blue',
#  'tab:red',
#  'tab:blue',
#  'tab:red',
#  'tab:orange',
#  'tab:green',
#  'tab:orange',
#  'tab:green',
#  'tab:orange',
#  'tab:red',
#  'tab:blue',
#  'tab:blue',
#  'tab:orange',
#  'tab:green',
#  'tab:orange',
#  'tab:green',
#  'tab:green',
#  'tab:blue',
#  'tab:green',
#  'tab:green',
#  'tab:blue',
#  'tab:orange',
#  'tab:red',
#  'tab:red',
#  'tab:green',
#  'tab:red',
#  'tab:orange',
#  'tab:red',
#  'tab:red',
#  'tab:red',
#  'tab:orange',
#  'tab:red',
#  'tab:red',
#  'tab:orange',
#  'tab:red',
#  'tab:red',
#  'tab:red',
#  'tab:red',
#  'tab:blue',
#  'tab:orange',
#  'tab:red',
#  'tab:orange',
#  'tab:orange',
#  'tab:green',
#  'tab:blue',
#  'tab:orange',
#  'tab:orange',
#  'tab:green',
#  'tab:green',
#  'tab:red',
#  'tab:orange',
#  'tab:red',
#  'tab:orange',
#  'tab:green',
#  'tab:red',
#  'tab:blue',
#  'tab:orange',
#  'tab:orange',
#  'tab:red',
#  'tab:green',
#  'tab:blue',
#  'tab:green',
#  'tab:red',
#  'tab:green',
#  'tab:red',
#  'tab:blue',
#  'tab:orange',
#  'tab:blue',
#  'tab:red',
#  'tab:blue',
#  'tab:red',
#  'tab:green',
#  'tab:green',
#  'tab:green',
#  'tab:green',
#  'tab:blue',
#  'tab:red',
#  'tab:blue',
#  'tab:orange',
#  'tab:green',
#  'tab:green',
#  'tab:orange',
#  'tab:red',
#  'tab:blue',
#  'tab:orange',
#  'tab:blue',
#  'tab:green',
#  'tab:orange',
#  'tab:orange',
#  'tab:green',
#  'tab:orange',
#  'tab:green',
#  'tab:orange',
#  'tab:blue',
#  'tab:red',
#  'tab:orange',
#  'tab:orange',
#  'tab:red',
#  'tab:green',
#  'tab:red',
#  'tab:orange',
#  'tab:green',
#  'tab:orange',
#  'tab:orange',
#  'tab:orange',
#  'tab:orange',
#  'tab:green',
#  'tab:green',
#  'tab:green',
#  'tab:red',
#  'tab:blue',
#  'tab:orange',
#  'tab:green',
#  'tab:orange',
#  'tab:green',
#  'tab:green',
#  'tab:blue',
#  'tab:orange',
#  'tab:orange',
#  'tab:red',
#  'tab:red',
#  'tab:green',
#  'tab:blue',
#  'tab:red',
#  'tab:green',
#  'tab:orange',
#  'tab:orange',
#  'tab:green',
#  'tab:orange',
#  'tab:green',
#  'tab:orange',
#  'tab:blue',
#  'tab:red',
#  'tab:blue',
#  'tab:red',
#  'tab:red',
#  'tab:orange',
#  'tab:red',
#  'tab:orange',
#  'tab:red',
#  'tab:red',
#  'tab:red',
#  'tab:red',
#  'tab:blue',
#  'tab:orange',
#  'tab:red',
#  'tab:red',
#  'tab:red',
#  'tab:red',
#  'tab:red',
#  'tab:red',
#  'tab:red',
#  'tab:red',
#  'tab:orange',
#  'tab:orange',
#  'tab:green',
#  'tab:orange',
#  'tab:red',
#  'tab:green',
#  'tab:red',
#  'tab:red',
#  'tab:red',
#  'tab:red',
#  'tab:green',
#  'tab:red',
#  'tab:red',
#  'tab:red',
#  'tab:green',
#  'tab:red',
#  'tab:red',
#  'tab:red',
#  'tab:red',
#  'tab:orange',
#  'tab:orange',
#  'tab:red',
#  'tab:red',
#  'tab:green',
#  'tab:green',
#  'tab:orange',
#  'tab:red',
#  'tab:blue',
#  'tab:red',
#  'tab:orange',
#  'tab:orange',
#  'tab:red',
#  'tab:blue',
#  'tab:blue',
#  'tab:green',
#  'tab:green',
#  'tab:blue',
#  'tab:red',
#  'tab:green',
#  'tab:green',
#  'tab:blue',
#  'tab:blue',
#  'tab:orange',
#  'tab:red',
#  'tab:red',
#  'tab:blue',
#  'tab:green',
#  'tab:blue',
#  'tab:blue',
#  'tab:red',
#  'tab:blue',
#  'tab:orange',
#  'tab:blue',
#  'tab:orange',
#  'tab:blue',
#  'tab:orange',
#  'tab:green',
#  'tab:blue',
#  'tab:red',
#  'tab:green',
#  'tab:red',
#  'tab:red',
#  'tab:red',
#  'tab:red',
#  'tab:green',
#  'tab:green',
#  'tab:green',
#  'tab:green',
#  'tab:red',
#  'tab:green',
#  'tab:green',
#  'tab:red',
#  'tab:orange',
#  'tab:orange',
#  'tab:blue',
#  'tab:blue',
#  'tab:red',
#  'tab:red',
#  'tab:orange',
#  'tab:orange',
#  'tab:green',
#  'tab:red',
#  'tab:red',
#  'tab:orange',
#  'tab:orange',
#  'tab:blue',
#  'tab:orange',
#  'tab:red',
#  'tab:orange',
#  'tab:orange',
#  'tab:orange',
#  'tab:green',
#  'tab:orange',
#  'tab:red',
#  'tab:orange',
#  'tab:red',
#  'tab:orange',
#  'tab:orange',
#  'tab:red',
#  'tab:orange',
#  'tab:orange',
#  'tab:green',
#  'tab:red',
#  'tab:blue',
#  'tab:blue',
#  'tab:red',
#  'tab:blue',
#  'tab:green',
#  'tab:blue',
#  'tab:blue',
#  'tab:green',
#  'tab:green',
#  'tab:orange',
#  'tab:orange',
#  'tab:green',
#  'tab:orange',
#  'tab:red',
#  'tab:orange',
#  'tab:orange',
#  'tab:red',
#  'tab:red',
#  'tab:orange',
#  'tab:green',
#  'tab:red',
#  'tab:green',
#  'tab:orange',
#  'tab:green',
#  'tab:green',
#  'tab:blue',
#  'tab:red',
#  'tab:green',
#  'tab:red',
#  'tab:red',
#  'tab:orange',
#  'tab:red',
#  'tab:orange',
#  'tab:green',
#  'tab:red',
#  'tab:green',
#  'tab:orange',
#  'tab:orange',
#  'tab:red',
#  'tab:green',
#  'tab:blue',
#  'tab:green',
#  'tab:blue',
#  'tab:orange',
#  'tab:green',
#  'tab:orange',
#  'tab:blue',
#  'tab:red',
#  'tab:green',
#  'tab:green',
#  'tab:green',
#  'tab:blue',
#  'tab:orange',
#  'tab:orange',
#  'tab:green',
#  'tab:green',
#  'tab:blue',
#  'tab:blue',
#  'tab:orange',
#  'tab:green',
#  'tab:red',
#  'tab:green',
#  'tab:green',
#  'tab:red',
#  'tab:blue',
#  'tab:red',
#  'tab:green',
#  'tab:green',
#  'tab:red',
#  'tab:orange',
#  'tab:orange',
#  'tab:red',
#  'tab:blue',
#  'tab:blue',
#  'tab:green',
#  'tab:red',
#  'tab:blue',
#  'tab:orange',
#  'tab:green',
#  'tab:orange',
#  'tab:blue',
#  'tab:orange',
#  'tab:blue',
#  'tab:green',
#  'tab:orange',
#  'tab:blue',
#  'tab:orange',
#  'tab:blue',
#  'tab:blue',
#  'tab:green',
#  'tab:green',
#  'tab:green',
#  'tab:green',
#  'tab:red',
#  'tab:green',
#  'tab:green',
#  'tab:red',
#  'tab:red',
#  'tab:orange',
#  'tab:green',
#  'tab:orange',
#  'tab:green',
#  'tab:red',
#  'tab:blue',
#  'tab:red',
#  'tab:red',
#  'tab:orange',
#  'tab:orange',
#  'tab:orange',
#  'tab:green',
#  'tab:blue',
#  'tab:green',
#  'tab:orange',
#  'tab:red',
#  'tab:red',
#  'tab:green',
#  'tab:red',
#  'tab:blue',
#  'tab:green',
#  'tab:blue',
#  'tab:green',
#  'tab:blue',
#  'tab:blue',
#  'tab:green',
#  'tab:red',
#  'tab:green',
#  'tab:green',
#  'tab:green',
#  'tab:blue',
#  'tab:red',
#  'tab:red',
#  'tab:green',
#  'tab:blue',
#  'tab:orange',
#  'tab:orange',
#  'tab:red',
#  'tab:red',
#  'tab:red',
#  'tab:red',
#  'tab:blue',
#  'tab:orange',
#  'tab:blue',
#  'tab:blue',
#  'tab:orange',
#  'tab:red',
#  'tab:red',
#  'tab:green',
#  'tab:orange',
#  'tab:red',
#  'tab:orange',
#  'tab:orange',
#  'tab:orange',
#  'tab:blue',
#  'tab:green',
#  'tab:orange',
#  'tab:orange',
#  'tab:red',
#  'tab:blue',
#  'tab:blue',
#  'tab:blue',
#  'tab:green',
#  'tab:orange',
#  'tab:orange',
#  'tab:green',
#  'tab:red',
#  'tab:orange',
#  'tab:orange',
#  'tab:orange',
#  'tab:red',
#  'tab:blue',
#  'tab:blue',
#  'tab:blue',
#  'tab:green',
#  'tab:red',
#  'tab:orange',
#  'tab:green',
#  'tab:orange',
#  'tab:green',
#  'tab:green',
#  'tab:orange',
#  'tab:green',
#  'tab:blue',
#  'tab:orange',
#  'tab:orange',
#  'tab:blue',
#  'tab:orange',
#  'tab:red',
#  'tab:blue',
#  'tab:orange',
#  'tab:green',
#  'tab:green',
#  'tab:blue',
#  'tab:blue',
#  'tab:orange',
#  'tab:blue',
#  'tab:red',
#  'tab:green',
#  'tab:green',
#  'tab:blue',
#  'tab:green',
#  'tab:blue',
#  'tab:green',
#  'tab:green',
#  'tab:orange',
#  'tab:blue',
#  'tab:green',
#  'tab:orange',
#  'tab:red',
#  'tab:red',
#  'tab:orange',
#  'tab:orange',
#  'tab:orange',
#  'tab:green',
#  'tab:green',
#  'tab:red',
#  'tab:green',
#  'tab:red',
#  'tab:orange',
#  'tab:orange',
#  'tab:red',
#  'tab:red',
#  'tab:orange',
#  'tab:red',
#  'tab:orange',
#  'tab:red',
#  'tab:red',
#  'tab:orange',
#  'tab:red',
#  'tab:blue',
#  'tab:orange',
#  'tab:blue',
#  'tab:red',
#  'tab:red',
#  'tab:red',
#  'tab:orange',
#  'tab:green',
#  'tab:blue',
#  'tab:red',
#  'tab:orange',
#  'tab:green',
#  'tab:green',
#  'tab:red',
#  'tab:red',
#  'tab:green',
#  'tab:orange',
#  'tab:red',
#  'tab:green',
#  'tab:blue',
#  'tab:orange',
#  'tab:green',
#  'tab:red',
#  'tab:orange',
#  'tab:blue',
#  'tab:green',
#  'tab:green',
#  'tab:orange',
#  'tab:green',
#  'tab:red',
#  'tab:blue',
#  'tab:red',
#  'tab:orange',
#  'tab:green',
#  'tab:orange',
#  'tab:red',
#  'tab:green',
#  'tab:green',
#  'tab:orange',
#  'tab:green',
#  'tab:green',
#  'tab:blue',
#  'tab:blue',
#  'tab:green',
#  'tab:orange',
#  'tab:blue',
#  'tab:orange',
#  'tab:green',
#  'tab:orange',
#  'tab:blue',
#  'tab:orange',
#  'tab:orange',
#  'tab:red',
#  'tab:red',
#  'tab:green',
#  'tab:red',
#  'tab:red',
#  'tab:orange',
#  'tab:red',
#  'tab:blue',
#  'tab:orange',
#  'tab:orange',
#  'tab:red',
#  'tab:orange',
#  'tab:orange',
#  'tab:red',
#  'tab:red',
#  'tab:orange',
#  'tab:orange',
#  'tab:green',
#  'tab:red',
#  'tab:red',
#  'tab:green',
#  'tab:red',
#  'tab:orange',
#  'tab:orange',
#  'tab:orange',
#  'tab:orange',
#  'tab:orange',
#  'tab:orange',
#  'tab:red',
#  'tab:orange',
#  'tab:green',
#  'tab:blue',
#  'tab:orange',
#  'tab:green',
#  'tab:green',
#  'tab:orange',
#  'tab:green',
#  'tab:blue',
#  'tab:orange',
#  'tab:blue',
#  'tab:red',
#  'tab:orange',
#  'tab:blue',
#  'tab:green',
#  'tab:orange',
#  'tab:red',
#  'tab:blue',
#  'tab:green',
#  'tab:blue',
#  'tab:orange',
#  'tab:green',
#  'tab:blue',
#  'tab:green',
#  'tab:orange',
#  'tab:red',
#  'tab:green',
#  'tab:green',
#  'tab:blue',
#  'tab:orange',
#  'tab:blue',
#  'tab:green',
#  'tab:red',
#  'tab:red',
#  'tab:red',
#  'tab:red',
#  'tab:green',
#  'tab:green',
#  'tab:green',
#  'tab:green',
#  'tab:green',
#  'tab:blue',
#  'tab:blue',
#  'tab:blue',
#  'tab:red',
#  'tab:blue',
#  'tab:green',
#  'tab:orange',
#  'tab:green',
#  'tab:blue',
#  'tab:blue',
#  'tab:green',
#  'tab:red',
#  'tab:blue',
#  'tab:red',
#  'tab:orange',
#  'tab:green',
#  'tab:orange',
#  'tab:orange',
#  'tab:red',
#  'tab:green',
#  'tab:blue',
#  'tab:green',
#  'tab:orange',
#  'tab:green',
#  'tab:red',
#  'tab:red',
#  'tab:green',
#  'tab:red',
#  'tab:red',
#  'tab:blue',
#  'tab:red',
#  'tab:green',
#  'tab:orange',
#  'tab:green',
#  'tab:orange',
#  'tab:red',
#  'tab:green',
#  'tab:blue',
#  'tab:red',
#  'tab:red',
#  'tab:green',
#  'tab:green',
#  'tab:red',
#  'tab:orange',
#  'tab:orange',
#  'tab:red',
#  'tab:blue',
#  'tab:green',
#  'tab:orange',
#  'tab:red',
#  'tab:green',
#  'tab:green',
#  'tab:red',
#  'tab:red',
#  'tab:green',
#  'tab:blue',
#  'tab:orange',
#  'tab:red',
#  'tab:blue',
#  'tab:orange',
#  'tab:red',
#  'tab:orange',
#  'tab:red',
#  'tab:orange',
#  'tab:orange',
#  'tab:blue',
#  'tab:orange',
#  'tab:green',
#  'tab:green',
#  'tab:green',
#  'tab:orange',
#  'tab:red',
#  'tab:green',
#  'tab:green',
#  'tab:blue',
#  'tab:red',
#  'tab:red',
#  'tab:green',
#  'tab:red',
#  'tab:red',
#  'tab:red',
#  'tab:orange',
#  'tab:red',
#  'tab:green',
#  'tab:red',
#  'tab:orange',
#  'tab:green',
#  'tab:orange',
#  'tab:red',
#  'tab:blue',
#  'tab:orange',
#  'tab:green',
#  'tab:orange',
#  'tab:blue',
#  'tab:blue',
#  'tab:red',
#  'tab:green',
#  'tab:orange',
#  'tab:orange',
#  'tab:green',
#  'tab:red',
#  'tab:blue',
#  'tab:orange',
#  'tab:green',
#  'tab:green',
#  'tab:green',
#  'tab:orange',
#  'tab:orange',
#  'tab:green',
#  'tab:red',
#  'tab:green',
#  'tab:blue',
#  'tab:blue',
#  'tab:orange',
#  'tab:orange',
#  'tab:red',
#  'tab:red',
#  'tab:blue',
#  'tab:orange',
#  'tab:red',
#  'tab:green',
#  'tab:green',
#  'tab:green',
#  'tab:orange',
#  'tab:blue',
#  'tab:green',
#  'tab:green',
#  'tab:green',
#  'tab:blue',
#  'tab:red',
#  'tab:green',
#  'tab:red',
#  'tab:blue',
#  'tab:red',
#  'tab:red',
#  'tab:red',
#  'tab:red',
#  'tab:blue',
#  'tab:green',
#  'tab:orange',
#  'tab:red',
#  'tab:orange',
#  'tab:orange',
#  'tab:orange',
#  'tab:blue',
#  'tab:green',
#  'tab:blue',
#  'tab:blue',
#  'tab:orange',
#  'tab:orange',
#  'tab:green',
#  'tab:blue',
#  'tab:orange',
#  'tab:red',
#  'tab:red',
#  'tab:green',
#  'tab:red',
#  'tab:red',
#  'tab:red',
#  'tab:green',
#  'tab:blue',
#  'tab:blue',
#  'tab:blue',
#  'tab:red',
#  'tab:blue',
#  'tab:red',
#  'tab:red',
#  'tab:red',
#  'tab:red',
#  'tab:orange',
#  'tab:orange',
#  'tab:red',
#  'tab:green',
#  'tab:red',
#  'tab:green',
#  'tab:green',
#  'tab:orange',
#  'tab:blue',
#  'tab:red',
#  'tab:orange',
#  'tab:blue',
#  'tab:green',
#  'tab:green',
#  'tab:orange',
#  'tab:green',
#  'tab:red',
#  'tab:green',
#  'tab:orange',
#  'tab:green',
#  'tab:blue',
#  'tab:green',
#  'tab:red',
#  'tab:green',
#  'tab:blue',
#  'tab:orange',
#  'tab:red',
#  'tab:green',
#  'tab:orange',
#  'tab:green',
#  'tab:orange',
#  'tab:red',
#  'tab:orange',
#  'tab:green',
#  'tab:orange',
#  'tab:blue',
#  'tab:blue',
#  'tab:green',
#  'tab:red',
#  'tab:orange',
#  'tab:green',
#  'tab:green',
#  'tab:green',
#  'tab:green',
#  'tab:blue',
#  'tab:orange',
#  'tab:orange',
#  'tab:orange',
#  'tab:green',
#  'tab:orange',
#  'tab:green',
#  'tab:blue',
#  'tab:blue',
#  'tab:blue',
#  'tab:orange',
#  'tab:blue',
#  'tab:orange',
#  'tab:green',
#  'tab:green',
#  'tab:green',
#  'tab:red',
#  'tab:green',
#  'tab:green',
#  'tab:blue',
#  'tab:red',
#  'tab:blue',
#  'tab:orange',
#  'tab:blue',
#  'tab:green',
#  'tab:orange',
#  'tab:blue',
#  'tab:green',
#  'tab:orange',
#  'tab:orange',
#  'tab:green',
#  'tab:orange',
#  'tab:blue',
#  'tab:red',
#  'tab:blue',
#  'tab:green',
#  'tab:orange',
#  'tab:red',
#  'tab:red',
#  'tab:orange',
#  'tab:orange',
#  'tab:red',
#  'tab:green',
#  'tab:green',
#  'tab:red',
#  'tab:blue',
#  'tab:green',
#  'tab:green',
#  'tab:blue',
#  'tab:orange',
#  'tab:orange',
#  'tab:blue',
#  'tab:orange',
#  ...]

# %% [markdown]
# # Plot PLS2 loadings
# The code below will create two side-by-side bar plots (ax1 and ax2) to visualize the loadings of the X variables for the first and second components. Each bar in the plot represents the loading value of a specific X variable, and the bars are colored based on a color scheme specified in the bar_colors list that relates to which protein panel the proteomic data is from.
#
# The color is determined by looking up the corresponding value in the lookup dictionary, which likely contains information about the X variables (aka their respective panels) and the associated colors assigned to these:
#
# colors = {"Inflammation": "tab:red", "Neurology": "tab:blue", "Cardiometabolic": "tab:orange", "Oncology": "tab:green"}

# %%
# Plot these loadings
# loadings of the X variables in the PLS2 model. 
# Loadings represent the contribution of each variable to the latent factors (components) extracted by PLS2. 
# focusing on the first two loadings ([:, 0] and [:, 1]), which are associated with the first and second components.

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

bar_colors =[lookup[i]['color'] for i in range(0,len(pls2.x_loadings_))]

ax1.bar(range(0, len(pls2.x_loadings_)), pls2.x_loadings_[:,0], width=20, color=bar_colors)
ax2.bar(range(0, len(pls2.x_loadings_)), pls2.x_loadings_[:,1], width=20, color=bar_colors)
# Out:
# <BarContainer object of 1464 artists>

# %% [markdown]
# ## Label plots: identify proteins with significant contributions

# %%
# Test code
import matplotlib.pyplot as plt

# Set your threshold value
threshold_value = 0.10  # Adjust this threshold as needed

# Create the figure and subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

# Create a list of bar colors based on values from the 'lookup' dictionary
bar_colors = [lookup[i]['color'] for i in range(len(pls2.x_loadings_))]

# Plot the first set of loadings
ax1.bar(range(len(pls2.x_loadings_)), pls2.x_loadings_[:, 0], width=20, color=bar_colors)
ax1.set_title('Component 1 Loadings')

# Plot the second set of loadings
ax2.bar(range(len(pls2.x_loadings_)), pls2.x_loadings_[:, 1], width=20, color=bar_colors)
ax2.set_title('Component 2 Loadings')

# Label the bars with protein names for those bars where the loading is greater than the threshold
for i, loading_value in enumerate(pls2.x_loadings_[:, 0]):
    if abs(loading_value) > threshold_value:
        ax1.annotate(proteins.columns[i], (i, loading_value), textcoords="offset points", xytext=(0, 10), ha='center')

for i, loading_value in enumerate(pls2.x_loadings_[:, 1]):
    if abs(loading_value) > threshold_value:
        ax2.annotate(proteins.columns[i], (i, loading_value), textcoords="offset points", xytext=(0, 10), ha='center')

# Adjust plot layout
plt.tight_layout()

# Show the plots
plt.show()

# %% [markdown]
# ## Scatter plot of Latent Variables (LVs)
#
# The scatter plot allows you to visualize the relationships between LVs derived from protein data and LVs derived from DTI data. Each point on the scatter plot represents a sample (or subject), and its position is determined by the values of the LVs for both datasets.
#
# PLS2 (Partial Least Squares Type 2) is a technique for integrating information from two or more datasets to identify associations or relationships between them. The scatter plot shows how well the LVs from the protein data align or correlate with the LVs from the DTI data. If there are clear patterns or clusters, it indicates a potential relationship between protein expression and DTI metrics.

# %%
lv_scores = pls2.x_scores_

# %%
import matplotlib.pyplot as plt

# Assuming 'lv_scores' contains the LV scores from your PLS2 model
# 'lv_scores' should be a two-dimensional array with LV scores in columns

# Extract the first and second LVs (columns 0 and 1)
lv1 = lv_scores[:, 0]
lv2 = lv_scores[:, 1]

# Create a scatter plot of LV1 vs. LV2
plt.figure(figsize=(8, 6))
plt.scatter(lv1, lv2, c='b', marker='o', label='LV1 vs. LV2')

# Add labels and title
plt.xlabel('LV1')
plt.ylabel('LV2')
plt.title('Scatter Plot of Latent Variables (LV1 vs. LV2)')

# Add legend if needed
plt.legend()

# Show the plot
plt.grid(True)
plt.show()

# %% [markdown]
# # Loadings plot

# %%
proteins.columns[i]
# Out:
# 'NMNAT1'

# %%
# Variable loadings plot

import matplotlib.pyplot as plt
import numpy as np

# Assuming 'pls2' is your fitted PLS2 model
# Extract variable loadings for the first LV (modify for other LVs)
variable_loadings = pls2.x_loadings_[:, 0]

# Extract variable names or labels from your data (modify as needed)
# Replace 'variable_names' with your actual variable names or labels
#variable_names = ['Variable1', 'Variable2', 'Variable3', ...]

variable_names = proteins.columns

#wm_cols = ["FMaj_FA", "FMin_FA", "lAR_FA", "lATR_FA", "lCingG_FA", "lCingPH_FA",
#           "lCST_FA", "lIFOF_FA", "lILF_FA", "lML_FA", "lPTR_FA", "lSLF_FA",
#           "lSTR_FA", "lUnc_FA", "MCP_FA", "rAR_FA", "rATR_FA", "rCingG_FA",
#           "rCingPH_FA", "rCST_FA", "rIFOF_FA", "rILF_FA", "rML_FA", "rPTR_FA",
#           "rSLF_FA", "rSTR_FA", "rUnc_FA"]

#proteins.columns[i]

# Create a bar plot of variable loadings
plt.figure(figsize=(10, 6))
plt.bar(np.arange(len(variable_loadings)), variable_loadings, color='b', alpha=0.7, align='center')

# Customize plot labels and title
plt.xlabel('X Variables')
plt.ylabel('Variable Loadings (LV1)')
plt.title('Variable Loadings Plot (LV1)')

# Add variable names as x-axis labels
plt.xticks(np.arange(len(variable_names)), variable_names, rotation=45, size=6)

# Show the plot
plt.tight_layout()
plt.show()

# %%
proteins.columns
# Out:
# Index(['Unnamed: 0', 'GZMB', 'GRPEL1', 'GSAP', 'GSTA1', 'GSTA3', 'GSTP1',
#        'GUCA2A', 'GUSB', 'GYS1',
#        ...
#        'PRDX1', 'NAAA', 'NGF', 'MITD1', 'MMP1', 'OBP2B', 'PCOLCE', 'PAEP',
#        'NPM1', 'NMNAT1'],
#       dtype='object', length=1464)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming 'pls2' is your fitted PLS2 regression model
# Extract regression coefficients (b-coefficients) for the first LV (modify for other LVs)
coefficients = pls2.coef_[:, 0]

# Extract variable names or labels from your data (modify as needed)
# Replace 'variable_names' with your actual variable names or labels
variable_names = ['Variable1', 'Variable2', 'Variable3', ...]
#variable_names = proteins.columns
variable_names = wm_cols

# Create a bar plot of regression coefficients
plt.figure(figsize=(10, 6))
plt.bar(np.arange(len(coefficients)), coefficients, color='b', alpha=0.7, align='center')

# Customize plot labels and title
plt.xlabel('X Variables')
plt.ylabel('Regression Coefficients (LV1)')
plt.title('Coefficient Plot (LV1)')

# Add variable names as x-axis labels
plt.xticks(np.arange(len(variable_names)), variable_names, rotation=90)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import numpy as np
from sklearn.cross_decomposition import PLSRegression
import matplotlib.pyplot as plt

# Assuming 'pls2' is your fitted PLS2 model
# Extract variable loadings
variable_loadings = pls2.x_loadings_

# Calculate the explained variance for each LV
explained_variance = np.var(variable_loadings, axis=0)

# Calculate VIP scores
n_lvs = len(explained_variance)
vip_scores = np.sqrt(n_lvs * np.sum(explained_variance, axis=1) / np.sum(explained_variance))

# Extract variable names or labels from your data (modify as needed)
# Replace 'variable_names' with your actual variable names or labels
# variable_names = ['Variable1', 'Variable2', 'Variable3', ...]
variable_names = proteins.columns

# Create a bar plot of VIP scores
plt.figure(figsize=(10, 6))
plt.bar(np.arange(len(vip_scores)), vip_scores, color='b', alpha=0.7, align='center')

# Customize plot labels and title
plt.xlabel('X Variables')
plt.ylabel('VIP Scores')
plt.title('VIP Plot')

# Add variable names as x-axis labels
plt.xticks(np.arange(len(variable_names)), variable_names, rotation=90)

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# Cell In[46], line 14
#      12 # Calculate VIP scores
#      13 n_lvs = len(explained_variance)
# ---> 14 vip_scores = np.sqrt(n_lvs * np.sum(explained_variance, axis=1) / np.sum(explained_variance))
#      16 # Extract variable names or labels from your data (modify as needed)
#      17 # Replace 'variable_names' with your actual variable names or labels
#      18 # variable_names = ['Variable1', 'Variable2', 'Variable3', ...]
#      19 variable_names = proteins.columns
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/core/fromnumeric.py:2313, in sum(a, axis, dtype, out, keepdims, initial, where)
#    2310         return out
#    2311     return res
# -> 2313 return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
#    2314                       initial=initial, where=where)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/core/fromnumeric.py:88, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85         else:
#      86             return reduction(axis=axis, out=out, **passkwargs)
# ---> 88 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# AxisError: axis 1 is out of bounds for array of dimension 1

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming 'pls2' is your fitted PLS2 model
# Extract VIP scores for the first LV (modify for other LVs)
vip_scores = pls2.vip_[:, 0]

# Extract variable names or labels from your data (modify as needed)
# Replace 'variable_names' with your actual variable names or labels
# variable_names = ['Variable1', 'Variable2', 'Variable3', ...]
variable_names = proteins.columns

# Create a bar plot of VIP scores
plt.figure(figsize=(10, 6))
plt.bar(np.arange(len(vip_scores)), vip_scores, color='b', alpha=0.7, align='center')

# Customize plot labels and title
plt.xlabel('X Variables')
plt.ylabel('VIP Scores (LV1)')
plt.title('VIP Plot (LV1)')

# Add variable names as x-axis labels
plt.xticks(np.arange(len(variable_names)), variable_names, rotation=90)

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 6
#       2 import numpy as np
#       4 # Assuming 'pls2' is your fitted PLS2 model
#       5 # Extract VIP scores for the first LV (modify for other LVs)
# ----> 6 vip_scores = pls2.vip_[:, 0]
#       8 # Extract variable names or labels from your data (modify as needed)
#       9 # Replace 'variable_names' with your actual variable names or labels
#      10 # variable_names = ['Variable1', 'Variable2', 'Variable3', ...]
#      11 variable_names = proteins.columns
#
# AttributeError: 'PLSRegression' object has no attribute 'vip_'

# %% [markdown]
# # Biplot

# %%
#Biplot
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cross_decomposition import PLSRegression

# Create and fit your PLS2 model (example)
#pls2 = PLSRegression(n_components=2)
#X = np.random.rand(50, 10)  # Sample data
#Y = np.random.rand(50, 5)   # Sample data
#pls2.fit(X, Y)

pls2 = PLSRegression(n_components=2)
pls2.fit(proteins, wm)

# Extract scores and loadings
scores = pls2.x_scores_
loadings = pls2.x_loadings_

# Create a biplot
plt.figure(figsize=(10, 8))

# Plot sample scores
plt.scatter(scores[:, 0], scores[:, 1], marker='o', c='b', label='Scores')

# Plot variable loadings as arrows
for i in range(len(loadings)):
    plt.arrow(0, 0, loadings[i, 0], loadings[i, 1], color='r', alpha=0.7)
    plt.text(loadings[i, 0], loadings[i, 1], f'Variable {i+1}', fontsize=12, color='r')

# Add labels and legend
plt.xlabel('LV1')
plt.ylabel('LV2')
plt.title('Biplot')
plt.legend(['Scores'])

plt.grid(True)
plt.show()

# %% [markdown]
# # Residuals plot

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cross_decomposition import PLSRegression

# Create and fit your PLS2 regression model (example)
# pls2 = PLSRegression(n_components=1)
# X = np.random.rand(50, 10)  # Sample data
# Y = np.random.rand(50, 1)   # Sample data
# pls2.fit(X, Y)

pls2 = PLSRegression(n_components=2)
pls2.fit(proteins, wm)

# Calculate residuals
y_predicted = pls2.predict(proteins)
residuals = wm - y_predicted

# Create a residuals plot
plt.figure(figsize=(8, 6))
plt.scatter(y_predicted, residuals, c='b', marker='o', label='Residuals')

# Add labels and title
plt.xlabel('Predicted Y')
plt.ylabel('Residuals')
plt.title('Residuals Plot')

# Add a horizontal line at y=0 for reference
plt.axhline(y=0, color='r', linestyle='--', linewidth=1)

# Show the plot
plt.legend()
plt.grid(True)
plt.show()

# %%
# Explained variance plot

import numpy as np
import matplotlib.pyplot as plt
from sklearn.cross_decomposition import PLSRegression

# Create and fit your PLS2 model (example)
# pls2 = PLSRegression(n_components=5)
# X = np.random.rand(50, 10)  # Sample data
# Y = np.random.rand(50, 5)   # Sample data
# pls2.fit(X, Y)

pls2 = PLSRegression(n_components=2)
pls2.fit(proteins, wm)
# Out:
# PLSRegression()

# %%
# Calculate explained variance for each LV

explained_variance = np.var(pls2.x_scores_, axis=0) / np.var(X, axis=0).sum()

# %%
# Create an explained variance plot
plt.figure(figsize=(8, 6))
plt.bar(np.arange(len(explained_variance)) + 1, explained_variance, color='b', alpha=0.7)

# Add labels and title
plt.xlabel('Latent Variable (LV)')
plt.ylabel('Explained Variance')
plt.title('Explained Variance Plot')

# Show the plot
plt.grid(True)
plt.show()

# %%
# Create an explained variance plot
plt.figure(figsize=(8, 6))
plt.bar(np.arange(len(explained_variance)) + 1, explained_variance, color='b', alpha=0.7)

# Add labels and title
plt.xlabel('Latent Variable (LV)')
plt.ylabel('Explained Variance')
plt.title('Explained Variance Plot')

# Show the plot
plt.grid(True)
plt.show()
